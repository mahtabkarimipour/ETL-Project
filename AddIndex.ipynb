# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\mvesk\Project2-ETL\ETL-Project\goal_detail.csv')


df.head()
# Out:
# C:\Users\mvesk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   comment  coordinates  del  elapsed  elapsed_plus  event_incident_typefk  \
# 0       n          NaN  NaN       22           NaN                    406
# 1       n          NaN  NaN       24           NaN                    393
# 2       n          NaN  NaN        4           NaN                    393
# 3       n          NaN  NaN       83           NaN                    407
# 4       n          NaN  NaN        4           NaN                    393
#
#    goal goal_type  goals      id  ...    pos_x  pos_y  shotoff  shoton  \
# 0   NaN         n    NaN  378998  ...      NaN    NaN      NaN     NaN
# 1   NaN         n    NaN  379019  ...      NaN    NaN      NaN     NaN
# ...

# %%
#df=df.rename(columns({}))
#df.rename(columns={'':'Prim_id'})
#df.head(5)
# Out:
#   comment  coordinates  del  elapsed  elapsed_plus  event_incident_typefk  \
# 0       n          NaN  NaN       22           NaN                    406
# 1       n          NaN  NaN       24           NaN                    393
# 2       n          NaN  NaN        4           NaN                    393
# 3       n          NaN  NaN       83           NaN                    407
# 4       n          NaN  NaN        4           NaN                    393
#
#    goal goal_type  goals      id  ...    pos_x  pos_y  shotoff  shoton  \
# 0   NaN         n    NaN  378998  ...      NaN    NaN      NaN     NaN
# 1   NaN         n    NaN  379019  ...      NaN    NaN      NaN     NaN
# 2   NaN         n    NaN  375546  ...      NaN    NaN      NaN     NaN
# 3   NaN         n    NaN  378041  ...      NaN    NaN      NaN     NaN
# 4   NaN         n    NaN  376060  ...      NaN    NaN      NaN     NaN
#
#    sortorder  stats   subtype     team  type  value
# ...

# %%
df.to_csv(r'C:\Users\mvesk\Project2-ETL\ETL-Project\goal_detail_redone.csv', index =True)
df.head()
# Out:
#   comment  coordinates  del  elapsed  elapsed_plus  event_incident_typefk  \
# 0       n          NaN  NaN       22           NaN                    406
# 1       n          NaN  NaN       24           NaN                    393
# 2       n          NaN  NaN        4           NaN                    393
# 3       n          NaN  NaN       83           NaN                    407
# 4       n          NaN  NaN        4           NaN                    393
#
#    goal goal_type  goals      id  ...    pos_x  pos_y  shotoff  shoton  \
# 0   NaN         n    NaN  378998  ...      NaN    NaN      NaN     NaN
# 1   NaN         n    NaN  379019  ...      NaN    NaN      NaN     NaN
# 2   NaN         n    NaN  375546  ...      NaN    NaN      NaN     NaN
# 3   NaN         n    NaN  378041  ...      NaN    NaN      NaN     NaN
# 4   NaN         n    NaN  376060  ...      NaN    NaN      NaN     NaN
#
#    sortorder  stats   subtype     team  type  value
# ...

# %%
#df = pd.read_csv(r'F:\goal_detail_redone.csv', index_col='prim_id')

#df.head(5)
# Out:
# C:\Users\mvesk\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   comment  coordinates  del  elapsed  elapsed_plus  event_incident_typefk  \
# 0       n          NaN  NaN       22           NaN                    406
# 1       n          NaN  NaN       24           NaN                    393
# 2       n          NaN  NaN        4           NaN                    393
# 3       n          NaN  NaN       83           NaN                    407
# 4       n          NaN  NaN        4           NaN                    393
#
#    goal goal_type  goals      id  ...    pos_x  pos_y  shotoff  shoton  \
# 0   NaN         n    NaN  378998  ...      NaN    NaN      NaN     NaN
# 1   NaN         n    NaN  379019  ...      NaN    NaN      NaN     NaN
# ...

# %%
df.set_index('', inplace=True)
#df.columns=['prim_id']
#df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d334dec55675> in <module>()
# ----> 1 df.set_index('', inplace=True)
#       2 #df.columns=['prim_id']
#       3 #df.head(5)
#
# NameError: name 'df' is not defined
